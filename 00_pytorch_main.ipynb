# %% [markdown]
# <a href="https://colab.research.google.com/github/cheeseybiscuits/Google-Colab-ML-DL-PyTorch-Journal/blob/updates/00_pytorch_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Welcome! 😊
#
# This Notebook goes over the basic fundamentals of Machine Learning/Deep Learning using PyTorch.
#
# I am following along freeCodeCamp.org's full course on Youtube: https://www.youtube.com/watch?v=V_xro1bcAuA
#
# I will section off topics and code in everything as such. There will be some required code blocks to run, but in general, everything basic will be here. I will (hopefully) make projects of my own once I am familiar enough with PyTorch and may even expand my horizons.

# %% [markdown]
# #Glossary (tbc)
#
# ###[PyTorch basics & fundamentals (tensors & tensor operations)](https://colab.research.google.com/drive/1xTpkWnWCixFwP4RtGv01FkhhlAMcydAs?usp=sharing)
#
# ###Preprocessing data (getting it into tenros)
#
# ###Building and using pretrained DL models
#
# ###Fitting a model to the data (learning patterns)
#
# ###Make predictions with a model (using patterns)
#
# ###Evaluating model predictions
#
# ###Saving & Learning models
#
# ###Using a trained model to make predictions on custom data
